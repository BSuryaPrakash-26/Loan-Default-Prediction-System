# %%
# Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import joblib
import os
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
# Importing Dataset

# %%
dataset=pd.read_csv("account_data.csv")

# %%
dataset
# Out:
#       Age          Occupation MaritalStatus  Dependents  ResidentialStatus  \
# 0      56             Teacher      Divorced           4                Own
# 1      40            Engineer        Single           0               Rent
# 2      25               Clerk       Married           0  Live with Parents
# 3      34          Unemployed        Single           0               Rent
# 4      47  Software Developer        Single           0               Rent
# ...   ...                 ...           ...         ...                ...
# 9995   53              Doctor      Divorced           0                Own
# 9996   56       Self-employed        Single           1                Own
# 9997   22             Student        Single           0               Rent
# 9998   40       Self-employed        Single           0               Rent
# 9999   56             Manager      Divorced           1                Own
#
#       AddressDuration  CreditScore  IncomeLevel  LoanAmountRequested  \
# 0                   1          827        52033               300000
# 1                   1          830        42893                 8105
# 2                 360          809       141233                75734
# 3                  92          630         9217                 2000
# 4                  26          733        47979                67767
# ...               ...          ...          ...                  ...
# 9995              134          749       109835                 2000
# 9996                1          749        65018                66029
# 9997               85          811            0                 2000
# 9998                1          757         6907                 7352
# 9999                1          807        62989               300000
#
#       LoanTerm  ... AccountActivity PaymentBehavior  Blacklists  \
# 0           25  ...          Normal         On-time          No
# 1            3  ...          Normal         On-time          No
# 2           19  ...          Normal         On-time         Yes
# 3            1  ...         Unusual       Defaulted          No
# 4            1  ...          Normal         On-time          No
# ...        ...  ...             ...             ...         ...
# 9995        24  ...          Normal         On-time          No
# 9996         5  ...          Normal            Late          No
# 9997         1  ...          Normal       Defaulted         Yes
# 9998        12  ...          Normal       Defaulted          No
# 9999        27  ...          Normal            Late          No
#
#       EmploymentVerification  PastFinancialMalpractices DeviceInformation  \
# 0                   Verified                         No            Tablet
# 1                   Verified                         No            Laptop
# 2                   Verified                         No            Laptop
# 3               Not Verified                        Yes            Mobile
# 4                   Verified                         No            Laptop
# ...                      ...                        ...               ...
# 9995                Verified                         No           Desktop
# 9996                Verified                         No           Desktop
# 9997            Not Verified                         No            Mobile
# 9998            Not Verified                         No            Mobile
# 9999                Verified                         No           Desktop
#
#      SocialMediaFootprint ConsistencyinData  Referral IsFraud
# 0                     Yes        Consistent  Referral      No
# 1                      No        Consistent    Online      No
# 2                      No        Consistent  Referral      No
# 3                      No      Inconsistent    Online     Yes
# 4                      No        Consistent    Online      No
# ...                   ...               ...       ...     ...
# 9995                   No        Consistent  Referral      No
# 9996                   No        Consistent  Referral      No
# 9997                   No      Inconsistent    Online     Yes
# 9998                  Yes      Inconsistent    Online     Yes
# 9999                   No        Consistent  Referral      No
#
# [10000 rows x 29 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 29 columns):
# Age                          10000 non-null int64
# Occupation                   10000 non-null object
# MaritalStatus                10000 non-null object
# Dependents                   10000 non-null int64
# ResidentialStatus            10000 non-null object
# AddressDuration              10000 non-null int64
# CreditScore                  10000 non-null int64
# IncomeLevel                  10000 non-null int64
# LoanAmountRequested          10000 non-null int64
# LoanTerm                     10000 non-null int64
# PurposeoftheLoan             10000 non-null object
# Collateral                   10000 non-null object
# InterestRate                 10000 non-null float64
# PreviousLoans                10000 non-null int64
# ExistingLiabilities          10000 non-null int64
# ApplicationBehavior          10000 non-null object
# LocationofApplication        10000 non-null object
# ChangeinBehavior             10000 non-null object
# TimeofTransaction            10000 non-null object
# AccountActivity              10000 non-null object
# PaymentBehavior              10000 non-null object
# Blacklists                   10000 non-null object
# EmploymentVerification       10000 non-null object
# PastFinancialMalpractices    10000 non-null object
# DeviceInformation            10000 non-null object
# SocialMediaFootprint         10000 non-null object
# ConsistencyinData            10000 non-null object
# Referral                     10000 non-null object
# IsFraud                      10000 non-null object
# dtypes: float64(1), int64(9), object(19)
# memory usage: 2.2+ MB

# %%
dataset.dropna(inplace=True)

# %%
dataset.isnull().sum()
# Out:
# Age                          0
# Occupation                   0
# MaritalStatus                0
# Dependents                   0
# ResidentialStatus            0
# AddressDuration              0
# CreditScore                  0
# IncomeLevel                  0
# LoanAmountRequested          0
# LoanTerm                     0
# PurposeoftheLoan             0
# Collateral                   0
# InterestRate                 0
# PreviousLoans                0
# ExistingLiabilities          0
# ApplicationBehavior          0
# LocationofApplication        0
# ChangeinBehavior             0
# TimeofTransaction            0
# AccountActivity              0
# PaymentBehavior              0
# Blacklists                   0
# EmploymentVerification       0
# PastFinancialMalpractices    0
# DeviceInformation            0
# SocialMediaFootprint         0
# ConsistencyinData            0
# Referral                     0
# IsFraud                      0
# dtype: int64

# %%
dataset.describe()
# Out:
#                 Age    Dependents  AddressDuration   CreditScore  \
# count  10000.000000  10000.000000     10000.000000  10000.000000
# mean      34.837900      1.323400        69.087400    768.701300
# std       12.631048      1.506399        84.854114     74.280933
# min       22.000000      0.000000         1.000000    580.000000
# 25%       22.000000      0.000000         1.000000    721.000000
# 50%       31.000000      1.000000        50.000000    801.000000
# 75%       45.000000      2.000000        86.000000    830.000000
# max       56.000000      4.000000       360.000000    830.000000
#
#          IncomeLevel  LoanAmountRequested      LoanTerm  InterestRate  \
# count   10000.000000         10000.000000  10000.000000  10000.000000
# mean    45994.615600         57218.915600     13.847700      5.149970
# std     44648.184654         72897.716564     10.923508      0.973665
# min         0.000000          2000.000000      1.000000      4.500000
# 25%      8277.500000         10555.000000      2.000000      4.500000
# 50%     32791.000000         44008.500000     13.000000      4.500000
# 75%     71698.000000         68073.750000     24.000000      5.600000
# max    150000.000000        300000.000000     30.000000      8.000000
#
#        PreviousLoans  ExistingLiabilities
# count   10000.000000         10000.000000
# mean        1.656900          3046.742500
# std         1.172996          2091.148502
# min         0.000000             0.000000
# 25%         1.000000          1222.000000
# 50%         1.000000          3231.000000
# 75%         2.000000          4545.250000
# max         4.000000          7000.000000

# %%
# Create a count plot
sns.set(style="darkgrid")  # Set the style of the plot
plt.figure(figsize=(8, 6))  # Set the figure size
# Replace 'dataset' with your actual DataFrame and 'Drug' with the column name
ax = sns.countplot(x='IsFraud', data=dataset, palette="Set3")
plt.title("Count Plot")  # Add a title to the plot
plt.xlabel("Categories")  # Add label to x-axis
plt.ylabel("Count")  # Add label to y-axis
# Annotate each bar with its count value
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')

plt.show()  # Display the plot

# %%
object_cols = dataset.select_dtypes(include=['object']).columns

# Apply Label Encoding to each object column
label_encoders = {}
for col in object_cols:
    le = LabelEncoder()
    dataset[col] = le.fit_transform(dataset[col])

# %%
from sklearn.utils import resample
dataset = resample(dataset, 
                        replace=True,     # sample with replacement
                        n_samples=40000,    # to match majority class
                        random_state=42) 
dataset
# Out:
#       Age  Occupation  MaritalStatus  Dependents  ResidentialStatus  \
# 7270   41           4              0           0                  2
# 860    38           3              1           4                  2
# 5390   56          16              1           1                  1
# 5191   35           1              1           4                  1
# 5734   25          13              2           0                  2
# ...   ...         ...            ...         ...                ...
# 9895   36          10              1           0                  1
# 4564   44           6              2           0                  1
# 5979   36           6              0           3                  1
# 8684   24           7              2           1                  1
# 3409   56          17              0           0                  1
#
#       AddressDuration  CreditScore  IncomeLevel  LoanAmountRequested  \
# 7270               62          830        15235                14960
# 860                 1          830        32192                 5359
# 5390              129          773        74309               300000
# 5191                1          678        49822                48642
# 5734               47          692        43317                 2000
# ...               ...          ...          ...                  ...
# 9895              308          830       150000                20358
# 4564               29          828        39937                49664
# 5979                1          830       150000               300000
# 8684                1          768         2930                 7854
# 3409               77          785       138563                 2000
#
#       LoanTerm  ...  AccountActivity  PaymentBehavior  Blacklists  \
# 7270         1  ...                0                2           0
# 860          5  ...                0                0           0
# 5390         1  ...                0                1           0
# 5191        21  ...                0                2           0
# 5734        10  ...                1                0           0
# ...        ...  ...              ...              ...         ...
# 9895        30  ...                0                2           0
# 4564        30  ...                0                2           0
# 5979        28  ...                0                2           0
# 8684         3  ...                0                1           0
# 3409         8  ...                0                2           0
#
#       EmploymentVerification  PastFinancialMalpractices  DeviceInformation  \
# 7270                       1                          0                  1
# 860                        1                          0                  2
# 5390                       1                          0                  0
# 5191                       1                          0                  2
# 5734                       0                          0                  2
# ...                      ...                        ...                ...
# 9895                       1                          0                  0
# 4564                       1                          0                  2
# 5979                       1                          0                  0
# 8684                       1                          0                  3
# 3409                       1                          0                  0
#
#       SocialMediaFootprint  ConsistencyinData  Referral  IsFraud
# 7270                     0                  1         0        0
# 860                      0                  1         0        0
# 5390                     0                  0         1        0
# 5191                     1                  0         0        0
# 5734                     0                  1         0        1
# ...                    ...                ...       ...      ...
# 9895                     0                  0         1        0
# 4564                     0                  1         0        0
# 5979                     1                  0         0        0
# 8684                     0                  1         0        0
# 3409                     0                  0         1        0
#
# [40000 rows x 29 columns]

# %%
X=dataset.iloc[:,0:28]

# %%
X
# Out:
#       Age  Occupation  MaritalStatus  Dependents  ResidentialStatus  \
# 7270   41           4              0           0                  2
# 860    38           3              1           4                  2
# 5390   56          16              1           1                  1
# 5191   35           1              1           4                  1
# 5734   25          13              2           0                  2
# ...   ...         ...            ...         ...                ...
# 9895   36          10              1           0                  1
# 4564   44           6              2           0                  1
# 5979   36           6              0           3                  1
# 8684   24           7              2           1                  1
# 3409   56          17              0           0                  1
#
#       AddressDuration  CreditScore  IncomeLevel  LoanAmountRequested  \
# 7270               62          830        15235                14960
# 860                 1          830        32192                 5359
# 5390              129          773        74309               300000
# 5191                1          678        49822                48642
# 5734               47          692        43317                 2000
# ...               ...          ...          ...                  ...
# 9895              308          830       150000                20358
# 4564               29          828        39937                49664
# 5979                1          830       150000               300000
# 8684                1          768         2930                 7854
# 3409               77          785       138563                 2000
#
#       LoanTerm  ...  TimeofTransaction  AccountActivity  PaymentBehavior  \
# 7270         1  ...                 27                0                2
# 860          5  ...                  8                0                0
# 5390         1  ...                 20                0                1
# 5191        21  ...                 19                0                2
# 5734        10  ...                  2                1                0
# ...        ...  ...                ...              ...              ...
# 9895        30  ...                 16                0                2
# 4564        30  ...                  8                0                2
# 5979        28  ...                 13                0                2
# 8684         3  ...                 12                0                1
# 3409         8  ...                  5                0                2
#
#       Blacklists  EmploymentVerification  PastFinancialMalpractices  \
# 7270           0                       1                          0
# 860            0                       1                          0
# 5390           0                       1                          0
# 5191           0                       1                          0
# 5734           0                       0                          0
# ...          ...                     ...                        ...
# 9895           0                       1                          0
# 4564           0                       1                          0
# 5979           0                       1                          0
# 8684           0                       1                          0
# 3409           0                       1                          0
#
#       DeviceInformation  SocialMediaFootprint  ConsistencyinData  Referral
# 7270                  1                     0                  1         0
# 860                   2                     0                  1         0
# 5390                  0                     0                  0         1
# 5191                  2                     1                  0         0
# 5734                  2                     0                  1         0
# ...                 ...                   ...                ...       ...
# 9895                  0                     0                  0         1
# 4564                  2                     0                  1         0
# 5979                  0                     1                  0         0
# 8684                  3                     0                  1         0
# 3409                  0                     0                  0         1
#
# [40000 rows x 28 columns]

# %%
y=dataset.iloc[:,-1]

# %%
y
# Out:
# 7270    0
# 860     0
# 5390    0
# 5191    0
# 5734    1
#        ..
# 9895    0
# 4564    0
# 5979    0
# 8684    0
# 3409    0
# Name: IsFraud, Length: 40000, dtype: int32

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE()
X,y = smote.fit_resample(X,y)

# %%
# Create a count plot
sns.set(style="darkgrid")  # Set the style of the plot
plt.figure(figsize=(8, 6))  # Set the figure size
# Replace 'dataset' with your actual DataFrame and 'Drug' with the column name
ax = sns.countplot(x=y, data=dataset, palette="Set3")
plt.title("Count Plot")  # Add a title to the plot
plt.xlabel("Categories")  # Add label to x-axis
plt.ylabel("Count")  # Add label to y-axis
# Annotate each bar with its count value
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')

plt.show()  # Display the plot

# %%
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.20)

# %%
X_train.shape
# Out:
# (49686, 28)

# %%
X_test.shape
# Out:
# (12422, 28)

# %%
y_train.shape
# Out:
# (49686,)

# %%
y_test.shape
# Out:
# (12422,)

# %%
#Building a ML Model

# %%
labels=['Normal','Fraud']

# %%
#defining global variables to store accuracy and other metrics
precision = []
recall = []
fscore = []
accuracy = []

# %%
#function to calculate various metrics such as accuracy, precision etc
def calculateMetrics(algorithm, predict, testY):
    testY = testY.astype('int')
    predict = predict.astype('int')
    p = precision_score(testY, predict,average='macro') * 100
    r = recall_score(testY, predict,average='macro') * 100
    f = f1_score(testY, predict,average='macro') * 100
    a = accuracy_score(testY,predict)*100 
    accuracy.append(a)
    precision.append(p)
    recall.append(r)
    fscore.append(f)
    print(algorithm+' Accuracy    : '+str(a))
    print(algorithm+' Precision   : '+str(p))
    print(algorithm+' Recall      : '+str(r))
    print(algorithm+' FSCORE      : '+str(f))
    report=classification_report(predict, testY,target_names=labels)
    print('\n',algorithm+" classification report\n",report)
    conf_matrix = confusion_matrix(testY, predict) 
    plt.figure(figsize =(5, 5)) 
    ax = sns.heatmap(conf_matrix, xticklabels = labels, yticklabels = labels, annot = True, cmap="Blues" ,fmt ="g");
    ax.set_ylim([0,len(labels)])
    plt.title(algorithm+" Confusion matrix") 
    plt.ylabel('True class') 
    plt.xlabel('Predicted class') 
    plt.show()

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
if os.path.exists('KNN.pkl'):
    # Load the trained model from the file
    clf = joblib.load('KNN.pkl')
    print("Model loaded successfully.")
    predict = clf.predict(X_test)
    calculateMetrics("KNN", predict, y_test)
else:
    # Train the model (assuming X_train and y_train are defined)
    clf = KNeighborsClassifier()
    clf.fit(X_train, y_train)
    # Save the trained model to a file
    joblib.dump(clf, 'KNN.pkl')
    print("Model saved successfully.")
    predict = clf.predict(X_test)
    calculateMetrics("KNN", predict, y_test)
# Out:
# Model loaded successfully.
# KNN Accuracy    : 79.68926098856866
# KNN Precision   : 80.47163994413526
# KNN Recall      : 79.77576653800564
# KNN FSCORE      : 79.5884468392129
#
#  KNN classification report
#                precision    recall  f1-score   support
#
#       Normal       0.72      0.86      0.78      5270
#        Fraud       0.88      0.75      0.81      7152
#
#     accuracy                           0.80     12422
#    macro avg       0.80      0.80      0.80     12422
# weighted avg       0.81      0.80      0.80     12422

# %% [markdown]
# # RFC Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
model_path = 'RandomForestClassifier1.pkl'
# Check if the model exists
if os.path.exists(model_path):
    # Load the trained model from the file
    clf = joblib.load(model_path)
    print("Model loaded successfully.")
else:
    # Train the model
    clf = RandomForestClassifier()
    clf.fit(X_train, y_train)
    # Save the trained model to a file
    joblib.dump(clf, model_path)
    print("Model saved successfully.")

# Make predictions on the test set
predict = clf.predict(X_test)

# Calculate and print metrics
calculateMetrics("Random Forest Classifier Classifier", predict, y_test)
# Out:
# Model loaded successfully.
# Random Forest Classifier Classifier Accuracy    : 99.70214136209951
# Random Forest Classifier Classifier Precision   : 99.70673324152169
# Random Forest Classifier Classifier Recall      : 99.69902050708058
# Random Forest Classifier Classifier FSCORE      : 99.70208490719504
#
#  Random Forest Classifier Classifier classification report
#                precision    recall  f1-score   support
#
#       Normal       1.00      0.99      1.00      6314
#        Fraud       0.99      1.00      1.00      6108
#
#     accuracy                           1.00     12422
#    macro avg       1.00      1.00      1.00     12422
# weighted avg       1.00      1.00      1.00     12422

# %%
#showing all algorithms performance values
columns = ["Algorithm Name","Accuracy","Precison","Recall","FScore"]
values = []
algorithm_names = ["KNN", "RFC Classifier"]
for i in range(len(algorithm_names)):
    values.append([algorithm_names[i],accuracy[i],precision[i],recall[i],fscore[i]])
    
temp = pd.DataFrame(values,columns=columns)
temp
# Out:
#    Algorithm Name   Accuracy   Precison     Recall     FScore
# 0             KNN  79.689261  80.471640  79.775767  79.588447
# 1  RFC Classifier  99.702141  99.706733  99.699021  99.702085

# %%
test=pd.read_csv("test1.csv")
test1=pd.read_csv("test1.csv")

# %%
test
# Out:
#     Age          Occupation MaritalStatus  Dependents ResidentialStatus  \
# 0    22              Artist        Single           1              Rent
# 1    22  Software Developer        Single           0               Own
# 2    29             Retired        Single           1               Own
# 3    45              Doctor      Divorced           4               Own
# 4    56                Chef        Single           4               Own
# 5    32             Retired        Single           1               Own
# 6    56             Manager      Divorced           2               Own
# 7    56          Technician        Single           0              Rent
# 8    56          Accountant      Divorced           4               Own
# 9    22               Clerk        Single           0              Rent
# 10   46            Engineer       Married           0               Own
# 11   23        Entrepreneur       Married           4               Own
# 12   55              Doctor      Divorced           0               Own
# 13   22             Teacher        Single           4              Rent
# 14   23             Manager        Single           1               Own
# 15   24          Technician        Single           0              Rent
# 16   22          Accountant        Single           1              Rent
# 17   56          Technician        Single           0              Rent
# 18   22            Designer        Single           1              Rent
# 19   40  Software Developer        Single           3               Own
# 20   22            Engineer        Single           1              Rent
# 21   36          Accountant        Single           0               Own
# 22   22          Accountant        Single           1              Rent
# 23   22            Engineer        Single           1              Rent
# 24   24             Manager        Single           1               Own
# 25   22              Doctor      Divorced           0               Own
# 26   28       Self-employed        Single           1              Rent
# 27   22          Technician        Single           0               Own
# 28   22            Musician        Single           0              Rent
# 29   22          Unemployed        Single           1              Rent
#
#     AddressDuration  CreditScore  IncomeLevel  LoanAmountRequested  LoanTerm  \
# 0                 1          821         2574                32622        17
# 1                62          679        35078                 2000        11
# 2                14          799        39309                26084        20
# 3                 1          830       150000                 2000        11
# 4                24          830          843                26799         3
# 5                 1          830        82921                11171         5
# 6                39          803        16935               300000        30
# 7                 3          830        54642                 4787        25
# 8               224          830        39942               300000         1
# 9                48          654         3042                71795        22
# 10               55          830        39726                47331         4
# 11              189          830        41336                57806         3
# 12              187          830        53599               300000        15
# 13               16          830        43276                37562         8
# 14                1          830        59808                75023        27
# 15               92          830        96900                58036         1
# 16                1          602            0                 2000         3
# 17               48          640         3617                 2000         1
# 18               86          715         6661                 2000         1
# 19               76          801            0                59702        12
# 20               73          765        41559                67984         1
# 21               92          720        29974                30306        22
# 22               90          659        28003                 2000        21
# 23               41          795        15309                 2000         1
# 24               83          761        47258                69114         6
# 25               37          830        68339                36646         4
# 26               68          736        11114                41581         1
# 27               88          627         6692                62698         5
# 28               78          691        10646                55832         4
# 29               85          818         7470                 2000         1
#
#     ... TimeofTransaction AccountActivity  PaymentBehavior  Blacklists  \
# 0   ...             02:00         Unusual          On-time          No
# 1   ...             03:00          Normal          On-time          No
# 2   ...             11:50          Normal             Late          No
# 3   ...             14:40          Normal             Late          No
# 4   ...             11:50          Normal          On-time          No
# 5   ...             09:40         Unusual          On-time          No
# 6   ...             10:50          Normal          On-time          No
# 7   ...             09:00          Normal          On-time          No
# 8   ...             15:30          Normal          On-time          No
# 9   ...             09:00         Unusual          On-time          No
# 10  ...             03:00          Normal          On-time          No
# 11  ...             09:30          Normal             Late          No
# 12  ...             12:45          Normal          On-time          No
# 13  ...             10:20          Normal          On-time          No
# 14  ...             10:20          Normal          On-time          No
# 15  ...             12:45          Normal             Late          No
# 16  ...             09:00          Normal             Late          No
# 17  ...             13:30          Normal          On-time          No
# 18  ...             03:00         Unusual        Defaulted          No
# 19  ...             13:30          Normal          On-time          No
# 20  ...             01:00          Normal          On-time          No
# 21  ...             16:30          Normal          On-time          No
# 22  ...             02:00         Unusual        Defaulted          No
# 23  ...             15:40         Unusual        Defaulted         Yes
# 24  ...             12:00          Normal          On-time          No
# 25  ...             14:00          Normal          On-time          No
# 26  ...             02:00          Normal          On-time         Yes
# 27  ...             16:00          Normal             Late          No
# 28  ...             09:40         Unusual        Defaulted         Yes
# 29  ...             11:00         Unusual        Defaulted          No
#
#     EmploymentVerification PastFinancialMalpractices DeviceInformation  \
# 0                 Verified                        No            Mobile
# 1                 Verified                        No           Desktop
# 2                 Verified                        No           Desktop
# 3                 Verified                        No           Desktop
# 4                 Verified                        No           Desktop
# 5                 Verified                        No            Mobile
# 6                 Verified                        No           Desktop
# 7                 Verified                        No           Desktop
# 8                 Verified                        No           Desktop
# 9                 Verified                        No           Desktop
# 10            Not Verified                        No            Mobile
# 11                Verified                        No           Desktop
# 12                Verified                        No           Desktop
# 13                Verified                        No            Laptop
# 14                Verified                        No           Desktop
# 15                Verified                        No            Mobile
# 16            Not Verified                        No            Laptop
# 17                Verified                        No           Desktop
# 18            Not Verified                        No            Mobile
# 19                Verified                        No           Desktop
# 20                Verified                        No           Desktop
# 21                Verified                        No           Desktop
# 22            Not Verified                       Yes            Mobile
# 23            Not Verified                        No            Mobile
# 24                Verified                        No            Mobile
# 25            Not Verified                        No           Desktop
# 26            Not Verified                        No            Mobile
# 27                Verified                        No            Mobile
# 28            Not Verified                        No            Mobile
# 29            Not Verified                        No            Mobile
#
#    SocialMediaFootprint ConsistencyinData  Referral
# 0                    No        Consistent    Online
# 1                    No      Inconsistent    Online
# 2                    No      Inconsistent    Online
# 3                    No        Consistent  Referral
# 4                    No        Consistent    Online
# 5                    No      Inconsistent    Online
# 6                   Yes        Consistent  Referral
# 7                   Yes        Consistent    Online
# 8                    No        Consistent  Referral
# 9                   Yes      Inconsistent    Online
# 10                   No        Consistent    Online
# 11                   No        Consistent  Referral
# 12                  Yes        Consistent  Referral
# 13                   No        Consistent    Online
# 14                   No        Consistent    Online
# 15                   No      Inconsistent    Online
# 16                   No      Inconsistent    Online
# 17                   No      Inconsistent    Online
# 18                   No      Inconsistent    Online
# 19                  Yes      Inconsistent    Online
# 20                   No      Inconsistent    Online
# 21                   No        Consistent    Online
# 22                   No      Inconsistent    Online
# 23                   No      Inconsistent    Online
# 24                   No        Consistent    Online
# 25                  Yes        Consistent    Online
# 26                   No      Inconsistent    Online
# 27                   No      Inconsistent    Online
# 28                   No      Inconsistent    Online
# 29                   No      Inconsistent    Online
#
# [30 rows x 28 columns]

# %%
object_cols = test1.select_dtypes(include=['object']).columns

# Apply Label Encoding to each object column
label_encoders = {}
for col in object_cols:
    le = LabelEncoder()
    test1[col] = le.fit_transform(test1[col])
predict = clf.predict(test1)

# Loop through each prediction and print the corresponding row
for i, p in enumerate(predict):
    if p == 0:
        print(test.iloc[i])
        print("Row {}:*************************************NO Fraud Detected".format(i))
        
    else:
        print(test.iloc[i])
        print("Row {}:**************************************Fraud Detected".format(i))
# Out:
# Age                                  22
# Occupation                       Artist
# MaritalStatus                    Single
# Dependents                            1
# ResidentialStatus                  Rent
# AddressDuration                       1
# CreditScore                         821
# IncomeLevel                        2574
# LoanAmountRequested               32622
# LoanTerm                             17
# PurposeoftheLoan               personal
# Collateral                           No
# InterestRate                        4.5
# PreviousLoans                         1
# ExistingLiabilities                   0
# ApplicationBehavior              Normal
# LocationofApplication             Local
# ChangeinBehavior                     No
# TimeofTransaction                 02:00
# AccountActivity                 Unusual
# PaymentBehavior                 On-time
# Blacklists                           No
# EmploymentVerification         Verified
# PastFinancialMalpractices            No
# DeviceInformation                Mobile
# SocialMediaFootprint                 No
# ConsistencyinData            Consistent
# Referral                         Online
# Name: 0, dtype: object
# Row 0:*************************************NO Fraud Detected
# Age                                          22
# Occupation                   Software Developer
# MaritalStatus                            Single
# Dependents                                    0
# ResidentialStatus                           Own
# AddressDuration                              62
# CreditScore                                 679
# IncomeLevel                               35078
# LoanAmountRequested                        2000
# LoanTerm                                     11
# PurposeoftheLoan                           auto
# Collateral                                   No
# InterestRate                                5.2
# PreviousLoans                                 2
# ExistingLiabilities                        4886
# ApplicationBehavior                      Normal
# LocationofApplication                     Local
# ChangeinBehavior                             No
# TimeofTransaction                         03:00
# AccountActivity                          Normal
# PaymentBehavior                         On-time
# Blacklists                                   No
# EmploymentVerification                 Verified
# PastFinancialMalpractices                    No
# DeviceInformation                       Desktop
# SocialMediaFootprint                         No
# ConsistencyinData                  Inconsistent
# Referral                                 Online
# Name: 1, dtype: object
# Row 1:*************************************NO Fraud Detected
# Age                                    29
# Occupation                        Retired
# MaritalStatus                      Single
# Dependents                              1
# ResidentialStatus                     Own
# AddressDuration                        14
# CreditScore                           799
# IncomeLevel                         39309
# LoanAmountRequested                 26084
# LoanTerm                               20
# PurposeoftheLoan                 personal
# Collateral                             No
# InterestRate                          4.9
# PreviousLoans                           1
# ExistingLiabilities                     0
# ApplicationBehavior                Normal
# LocationofApplication             Unusual
# ChangeinBehavior                       No
# TimeofTransaction                   11:50
# AccountActivity                    Normal
# PaymentBehavior                      Late
# Blacklists                             No
# EmploymentVerification           Verified
# PastFinancialMalpractices              No
# DeviceInformation                 Desktop
# SocialMediaFootprint                   No
# ConsistencyinData            Inconsistent
# Referral                           Online
# Name: 2, dtype: object
# Row 2:*************************************NO Fraud Detected
# Age                                  45
# Occupation                       Doctor
# MaritalStatus                  Divorced
# Dependents                            4
# ResidentialStatus                   Own
# AddressDuration                       1
# CreditScore                         830
# IncomeLevel                      150000
# LoanAmountRequested                2000
# LoanTerm                             11
# PurposeoftheLoan                   home
# Collateral                           No
# InterestRate                        4.5
# PreviousLoans                         2
# ExistingLiabilities                   0
# ApplicationBehavior              Normal
# LocationofApplication             Local
# ChangeinBehavior                    Yes
# TimeofTransaction                 14:40
# AccountActivity                  Normal
# PaymentBehavior                    Late
# Blacklists                           No
# EmploymentVerification         Verified
# PastFinancialMalpractices            No
# DeviceInformation               Desktop
# SocialMediaFootprint                 No
# ConsistencyinData            Consistent
# Referral                       Referral
# Name: 3, dtype: object
# Row 3:*************************************NO Fraud Detected
# Age                                  56
# Occupation                         Chef
# MaritalStatus                    Single
# Dependents                            4
# ResidentialStatus                   Own
# AddressDuration                      24
# CreditScore                         830
# IncomeLevel                         843
# LoanAmountRequested               26799
# LoanTerm                              3
# PurposeoftheLoan                   home
# Collateral                          Yes
# InterestRate                        4.5
# PreviousLoans                         2
# ExistingLiabilities                2802
# ApplicationBehavior              Normal
# LocationofApplication             Local
# ChangeinBehavior                     No
# TimeofTransaction                 11:50
# AccountActivity                  Normal
# PaymentBehavior                 On-time
# Blacklists                           No
# EmploymentVerification         Verified
# PastFinancialMalpractices            No
# DeviceInformation               Desktop
# SocialMediaFootprint                 No
# ConsistencyinData            Consistent
# Referral                         Online
# Name: 4, dtype: object
# Row 4:*************************************NO Fraud Detected
# Age                                    32
# Occupation                        Retired
# MaritalStatus                      Single
# Dependents                              1
# ResidentialStatus                     Own
# AddressDuration                         1
# CreditScore                           830
# IncomeLevel                         82921
# LoanAmountRequested                 11171
# LoanTerm                                5
# PurposeoftheLoan                     auto
# Collateral                             No
# InterestRate                          4.5
# PreviousLoans                           1
# ExistingLiabilities                  2177
# ApplicationBehavior                Normal
# LocationofApplication               Local
# ChangeinBehavior                       No
# TimeofTransaction                   09:40
# AccountActivity                   Unusual
# PaymentBehavior                   On-time
# Blacklists                             No
# EmploymentVerification           Verified
# PastFinancialMalpractices              No
# DeviceInformation                  Mobile
# SocialMediaFootprint                   No
# ConsistencyinData            Inconsistent
# Referral                           Online
# Name: 5, dtype: object
# Row 5:*************************************NO Fraud Detected
# Age                                  56
# Occupation                      Manager
# MaritalStatus                  Divorced
# Dependents                            2
# ResidentialStatus                   Own
# AddressDuration                      39
# CreditScore                         803
# IncomeLevel                       16935
# LoanAmountRequested              300000
# LoanTerm                             30
# PurposeoftheLoan                   home
# Collateral                          Yes
# InterestRate                        4.7
# PreviousLoans                         2
# ExistingLiabilities                6815
# ApplicationBehavior              Normal
# LocationofApplication             Local
# ChangeinBehavior                    Yes
# TimeofTransaction                 10:50
# AccountActivity                  Normal
# PaymentBehavior                 On-time
# Blacklists                           No
# EmploymentVerification         Verified
# PastFinancialMalpractices            No
# DeviceInformation               Desktop
# SocialMediaFootprint                Yes
# ConsistencyinData            Consistent
# Referral                       Referral
# Name: 6, dtype: object
# Row 6:*************************************NO Fraud Detected
# Age                                  56
# Occupation                   Technician
# MaritalStatus                    Single
# Dependents                            0
# ResidentialStatus                  Rent
# AddressDuration                       3
# CreditScore                         830
# IncomeLevel                       54642
# LoanAmountRequested                4787
# LoanTerm                             25
# PurposeoftheLoan                   home
# Collateral                          Yes
# InterestRate                        5.2
# PreviousLoans                         4
# ExistingLiabilities                3181
# ApplicationBehavior               Rapid
# LocationofApplication             Local
# ChangeinBehavior                     No
# TimeofTransaction                 09:00
# AccountActivity                  Normal
# PaymentBehavior                 On-time
# Blacklists                           No
# EmploymentVerification         Verified
# PastFinancialMalpractices            No
# DeviceInformation               Desktop
# SocialMediaFootprint                Yes
# ConsistencyinData            Consistent
# Referral                         Online
# Name: 7, dtype: object
# Row 7:*************************************NO Fraud Detected
# Age                                  56
# Occupation                   Accountant
# MaritalStatus                  Divorced
# Dependents                            4
# ResidentialStatus                   Own
# AddressDuration                     224
# CreditScore                         830
# IncomeLevel                       39942
# LoanAmountRequested              300000
# LoanTerm                              1
# PurposeoftheLoan                   home
# Collateral                          Yes
# InterestRate                        4.5
# PreviousLoans                         1
# ExistingLiabilities                7000
# ApplicationBehavior              Normal
# LocationofApplication             Local
# ChangeinBehavior                     No
# TimeofTransaction                 15:30
# AccountActivity                  Normal
# PaymentBehavior                 On-time
# Blacklists                           No
# EmploymentVerification         Verified
# PastFinancialMalpractices            No
# DeviceInformation               Desktop
# SocialMediaFootprint                 No
# ConsistencyinData            Consistent
# Referral                       Referral
# Name: 8, dtype: object
# Row 8:*************************************NO Fraud Detected
# Age                                    22
# Occupation                          Clerk
# MaritalStatus                      Single
# Dependents                              0
# ResidentialStatus                    Rent
# AddressDuration                        48
# CreditScore                           654
# IncomeLevel                          3042
# LoanAmountRequested                 71795
# LoanTerm                               22
# PurposeoftheLoan                education
# Collateral                             No
# InterestRate                          5.1
# PreviousLoans                           1
# ExistingLiabilities                  3983
# ApplicationBehavior                Normal
# LocationofApplication             Unusual
# ChangeinBehavior                       No
# TimeofTransaction                   09:00
# AccountActivity                   Unusual
# PaymentBehavior                   On-time
# Blacklists                             No
# EmploymentVerification           Verified
# PastFinancialMalpractices              No
# DeviceInformation                 Desktop
# SocialMediaFootprint                  Yes
# ConsistencyinData            Inconsistent
# Referral                           Online
# Name: 9, dtype: object
# Row 9:*************************************NO Fraud Detected
# Age                                    46
# Occupation                       Engineer
# MaritalStatus                     Married
# Dependents                              0
# ResidentialStatus                     Own
# AddressDuration                        55
# CreditScore                           830
# IncomeLevel                         39726
# LoanAmountRequested                 47331
# LoanTerm                                4
# PurposeoftheLoan                     home
# Collateral                             No
# InterestRate                          5.1
# PreviousLoans                           2
# ExistingLiabilities                  2732
# ApplicationBehavior                 Rapid
# LocationofApplication               Local
# ChangeinBehavior                       No
# TimeofTransaction                   03:00
# AccountActivity                    Normal
# PaymentBehavior                   On-time
# Blacklists                             No
# EmploymentVerification       Not Verified
# PastFinancialMalpractices              No
# DeviceInformation                  Mobile
# SocialMediaFootprint                   No
# ConsistencyinData              Consistent
# Referral                           Online
# Name: 10, dtype: object
# Row 10:*************************************NO Fraud Detected
# Age                                    23
# Occupation                   Entrepreneur
# MaritalStatus                     Married
# Dependents                              4
# ResidentialStatus                     Own
# AddressDuration                       189
# CreditScore                           830
# IncomeLevel                         41336
# LoanAmountRequested                 57806
# LoanTerm                                3
# PurposeoftheLoan                  medical
# Collateral                            Yes
# InterestRate                          4.5
# PreviousLoans                           3
# ExistingLiabilities                  6070
# ApplicationBehavior                 Rapid
# LocationofApplication               Local
# ChangeinBehavior                      Yes
# TimeofTransaction                   09:30
# AccountActivity                    Normal
# PaymentBehavior                      Late
# Blacklists                             No
# EmploymentVerification           Verified
# PastFinancialMalpractices              No
# DeviceInformation                 Desktop
# SocialMediaFootprint                   No
# ConsistencyinData              Consistent
# Referral                         Referral
# Name: 11, dtype: object
# Row 11:*************************************NO Fraud Detected
# Age                                  55
# Occupation                       Doctor
# MaritalStatus                  Divorced
# Dependents                            0
# ResidentialStatus                   Own
# AddressDuration                     187
# CreditScore                         830
# IncomeLevel                       53599
# LoanAmountRequested              300000
# LoanTerm                             15
# PurposeoftheLoan                   home
# Collateral                          Yes
# InterestRate                        6.1
# PreviousLoans                         2
# ExistingLiabilities                5023
# ApplicationBehavior              Normal
# LocationofApplication             Local
# ChangeinBehavior                     No
# TimeofTransaction                 12:45
# AccountActivity                  Normal
# PaymentBehavior                 On-time
# Blacklists                           No
# EmploymentVerification         Verified
# PastFinancialMalpractices            No
# DeviceInformation               Desktop
# SocialMediaFootprint                Yes
# ConsistencyinData            Consistent
# Referral                       Referral
# Name: 12, dtype: object
# Row 12:*************************************NO Fraud Detected
# Age                                  22
# Occupation                      Teacher
# MaritalStatus                    Single
# Dependents                            4
# ResidentialStatus                  Rent
# AddressDuration                      16
# CreditScore                         830
# IncomeLevel                       43276
# LoanAmountRequested               37562
# LoanTerm                              8
# PurposeoftheLoan               personal
# Collateral                           No
# InterestRate                        4.5
# PreviousLoans                         1
# ExistingLiabilities                 368
# ApplicationBehavior              Normal
# LocationofApplication             Local
# ChangeinBehavior                     No
# TimeofTransaction                 10:20
# AccountActivity                  Normal
# PaymentBehavior                 On-time
# Blacklists                           No
# EmploymentVerification         Verified
# PastFinancialMalpractices            No
# DeviceInformation                Laptop
# SocialMediaFootprint                 No
# ConsistencyinData            Consistent
# Referral                         Online
# Name: 13, dtype: object
# Row 13:*************************************NO Fraud Detected
# Age                                  23
# Occupation                      Manager
# MaritalStatus                    Single
# Dependents                            1
# ResidentialStatus                   Own
# AddressDuration                       1
# CreditScore                         830
# IncomeLevel                       59808
# LoanAmountRequested               75023
# LoanTerm                             27
# PurposeoftheLoan                   home
# Collateral                           No
# InterestRate                        4.5
# PreviousLoans                         1
# ExistingLiabilities                 632
# ApplicationBehavior              Normal
# LocationofApplication             Local
# ChangeinBehavior                    Yes
# TimeofTransaction                 10:20
# AccountActivity                  Normal
# PaymentBehavior                 On-time
# Blacklists                           No
# EmploymentVerification         Verified
# PastFinancialMalpractices            No
# DeviceInformation               Desktop
# SocialMediaFootprint                 No
# ConsistencyinData            Consistent
# Referral                         Online
# Name: 14, dtype: object
# Row 14:*************************************NO Fraud Detected
# Age                                    24
# Occupation                     Technician
# MaritalStatus                      Single
# Dependents                              0
# ResidentialStatus                    Rent
# AddressDuration                        92
# CreditScore                           830
# IncomeLevel                         96900
# LoanAmountRequested                 58036
# LoanTerm                                1
# PurposeoftheLoan                   travel
# Collateral                             No
# InterestRate                          6.5
# PreviousLoans                           2
# ExistingLiabilities                     0
# ApplicationBehavior                 Rapid
# LocationofApplication             Unusual
# ChangeinBehavior                       No
# TimeofTransaction                   12:45
# AccountActivity                    Normal
# PaymentBehavior                      Late
# Blacklists                             No
# EmploymentVerification           Verified
# PastFinancialMalpractices              No
# DeviceInformation                  Mobile
# SocialMediaFootprint                   No
# ConsistencyinData            Inconsistent
# Referral                           Online
# Name: 15, dtype: object
# Row 15:*************************************NO Fraud Detected
# Age                                    22
# Occupation                     Accountant
# MaritalStatus                      Single
# Dependents                              1
# ResidentialStatus                    Rent
# AddressDuration                         1
# CreditScore                           602
# IncomeLevel                             0
# LoanAmountRequested                  2000
# LoanTerm                                3
# PurposeoftheLoan                     auto
# Collateral                             No
# InterestRate                          4.5
# PreviousLoans                           2
# ExistingLiabilities                  4739
# ApplicationBehavior                 Rapid
# LocationofApplication               Local
# ChangeinBehavior                       No
# TimeofTransaction                   09:00
# AccountActivity                    Normal
# PaymentBehavior                      Late
# Blacklists                             No
# EmploymentVerification       Not Verified
# PastFinancialMalpractices              No
# DeviceInformation                  Laptop
# SocialMediaFootprint                   No
# ConsistencyinData            Inconsistent
# Referral                           Online
# Name: 16, dtype: object
# Row 16:**************************************Fraud Detected
# Age                                    56
# Occupation                     Technician
# MaritalStatus                      Single
# Dependents                              0
# ResidentialStatus                    Rent
# AddressDuration                        48
# CreditScore                           640
# IncomeLevel                          3617
# LoanAmountRequested                  2000
# LoanTerm                                1
# PurposeoftheLoan                     auto
# Collateral                             No
# InterestRate                          4.5
# PreviousLoans                           1
# ExistingLiabilities                  3717
# ApplicationBehavior                Normal
# LocationofApplication             Unusual
# ChangeinBehavior                       No
# TimeofTransaction                   13:30
# AccountActivity                    Normal
# PaymentBehavior                   On-time
# Blacklists                             No
# EmploymentVerification           Verified
# PastFinancialMalpractices              No
# DeviceInformation                 Desktop
# SocialMediaFootprint                   No
# ConsistencyinData            Inconsistent
# Referral                           Online
# Name: 17, dtype: object
# Row 17:*************************************NO Fraud Detected
# Age                                    22
# Occupation                       Designer
# MaritalStatus                      Single
# Dependents                              1
# ResidentialStatus                    Rent
# AddressDuration                        86
# CreditScore                           715
# IncomeLevel                          6661
# LoanAmountRequested                  2000
# LoanTerm                                1
# PurposeoftheLoan                 personal
# Collateral                             No
# InterestRate                          4.7
# PreviousLoans                           2
# ExistingLiabilities                  4833
# ApplicationBehavior                Normal
# LocationofApplication             Unusual
# ChangeinBehavior                       No
# TimeofTransaction                   03:00
# AccountActivity                   Unusual
# PaymentBehavior                 Defaulted
# Blacklists                             No
# EmploymentVerification       Not Verified
# PastFinancialMalpractices              No
# DeviceInformation                  Mobile
# SocialMediaFootprint                   No
# ConsistencyinData            Inconsistent
# Referral                           Online
# Name: 18, dtype: object
# Row 18:**************************************Fraud Detected
# Age                                          40
# Occupation                   Software Developer
# MaritalStatus                            Single
# Dependents                                    3
# ResidentialStatus                           Own
# AddressDuration                              76
# CreditScore                                 801
# IncomeLevel                                   0
# LoanAmountRequested                       59702
# LoanTerm                                     12
# PurposeoftheLoan                       personal
# Collateral                                   No
# InterestRate                                4.7
# PreviousLoans                                 4
# ExistingLiabilities                        5171
# ApplicationBehavior                      Normal
# LocationofApplication                   Unusual
# ChangeinBehavior                             No
# TimeofTransaction                         13:30
# AccountActivity                          Normal
# PaymentBehavior                         On-time
# Blacklists                                   No
# EmploymentVerification                 Verified
# PastFinancialMalpractices                    No
# DeviceInformation                       Desktop
# SocialMediaFootprint                        Yes
# ConsistencyinData                  Inconsistent
# Referral                                 Online
# Name: 19, dtype: object
# Row 19:**************************************Fraud Detected
# Age                                    22
# Occupation                       Engineer
# MaritalStatus                      Single
# Dependents                              1
# ResidentialStatus                    Rent
# AddressDuration                        73
# CreditScore                           765
# IncomeLevel                         41559
# LoanAmountRequested                 67984
# LoanTerm                                1
# PurposeoftheLoan                     auto
# Collateral                             No
# InterestRate                          4.5
# PreviousLoans                           0
# ExistingLiabilities                  2802
# ApplicationBehavior                Normal
# LocationofApplication             Unusual
# ChangeinBehavior                       No
# TimeofTransaction                   01:00
# AccountActivity                    Normal
# PaymentBehavior                   On-time
# Blacklists                             No
# EmploymentVerification           Verified
# PastFinancialMalpractices              No
# DeviceInformation                 Desktop
# SocialMediaFootprint                   No
# ConsistencyinData            Inconsistent
# Referral                           Online
# Name: 20, dtype: object
# Row 20:**************************************Fraud Detected
# Age                                  36
# Occupation                   Accountant
# MaritalStatus                    Single
# Dependents                            0
# ResidentialStatus                   Own
# AddressDuration                      92
# CreditScore                         720
# IncomeLevel                       29974
# LoanAmountRequested               30306
# LoanTerm                             22
# PurposeoftheLoan                   home
# Collateral                           No
# InterestRate                        4.6
# PreviousLoans                         2
# ExistingLiabilities                4365
# ApplicationBehavior              Normal
# LocationofApplication             Local
# ChangeinBehavior                     No
# TimeofTransaction                 16:30
# AccountActivity                  Normal
# PaymentBehavior                 On-time
# Blacklists                           No
# EmploymentVerification         Verified
# PastFinancialMalpractices            No
# DeviceInformation               Desktop
# SocialMediaFootprint                 No
# ConsistencyinData            Consistent
# Referral                         Online
# Name: 21, dtype: object
# Row 21:*************************************NO Fraud Detected
# Age                                    22
# Occupation                     Accountant
# MaritalStatus                      Single
# Dependents                              1
# ResidentialStatus                    Rent
# AddressDuration                        90
# CreditScore                           659
# IncomeLevel                         28003
# LoanAmountRequested                  2000
# LoanTerm                               21
# PurposeoftheLoan                 personal
# Collateral                             No
# InterestRate                          5.2
# PreviousLoans                           2
# ExistingLiabilities                  4748
# ApplicationBehavior                Normal
# LocationofApplication             Unusual
# ChangeinBehavior                       No
# TimeofTransaction                   02:00
# AccountActivity                   Unusual
# PaymentBehavior                 Defaulted
# Blacklists                             No
# EmploymentVerification       Not Verified
# PastFinancialMalpractices             Yes
# DeviceInformation                  Mobile
# SocialMediaFootprint                   No
# ConsistencyinData            Inconsistent
# Referral                           Online
# Name: 22, dtype: object
# Row 22:**************************************Fraud Detected
# Age                                    22
# Occupation                       Engineer
# MaritalStatus                      Single
# Dependents                              1
# ResidentialStatus                    Rent
# AddressDuration                        41
# CreditScore                           795
# IncomeLevel                         15309
# LoanAmountRequested                  2000
# LoanTerm                                1
# PurposeoftheLoan                     auto
# Collateral                             No
# InterestRate                          4.8
# PreviousLoans                           0
# ExistingLiabilities                  3737
# ApplicationBehavior                Normal
# LocationofApplication             Unusual
# ChangeinBehavior                       No
# TimeofTransaction                   15:40
# AccountActivity                   Unusual
# PaymentBehavior                 Defaulted
# Blacklists                            Yes
# EmploymentVerification       Not Verified
# PastFinancialMalpractices              No
# DeviceInformation                  Mobile
# SocialMediaFootprint                   No
# ConsistencyinData            Inconsistent
# Referral                           Online
# Name: 23, dtype: object
# Row 23:**************************************Fraud Detected
# Age                                  24
# Occupation                      Manager
# MaritalStatus                    Single
# Dependents                            1
# ResidentialStatus                   Own
# AddressDuration                      83
# CreditScore                         761
# IncomeLevel                       47258
# LoanAmountRequested               69114
# LoanTerm                              6
# PurposeoftheLoan                   home
# Collateral                           No
# InterestRate                        5.6
# PreviousLoans                         0
# ExistingLiabilities                   0
# ApplicationBehavior               Rapid
# LocationofApplication             Local
# ChangeinBehavior                     No
# TimeofTransaction                 12:00
# AccountActivity                  Normal
# PaymentBehavior                 On-time
# Blacklists                           No
# EmploymentVerification         Verified
# PastFinancialMalpractices            No
# DeviceInformation                Mobile
# SocialMediaFootprint                 No
# ConsistencyinData            Consistent
# Referral                         Online
# Name: 24, dtype: object
# Row 24:**************************************Fraud Detected
# Age                                    22
# Occupation                         Doctor
# MaritalStatus                    Divorced
# Dependents                              0
# ResidentialStatus                     Own
# AddressDuration                        37
# CreditScore                           830
# IncomeLevel                         68339
# LoanAmountRequested                 36646
# LoanTerm                                4
# PurposeoftheLoan                 personal
# Collateral                             No
# InterestRate                          4.5
# PreviousLoans                           1
# ExistingLiabilities                  3815
# ApplicationBehavior                Normal
# LocationofApplication               Local
# ChangeinBehavior                       No
# TimeofTransaction                   14:00
# AccountActivity                    Normal
# PaymentBehavior                   On-time
# Blacklists                             No
# EmploymentVerification       Not Verified
# PastFinancialMalpractices              No
# DeviceInformation                 Desktop
# SocialMediaFootprint                  Yes
# ConsistencyinData              Consistent
# Referral                           Online
# Name: 25, dtype: object
# Row 25:**************************************Fraud Detected
# Age                                     28
# Occupation                   Self-employed
# MaritalStatus                       Single
# Dependents                               1
# ResidentialStatus                     Rent
# AddressDuration                         68
# CreditScore                            736
# IncomeLevel                          11114
# LoanAmountRequested                  41581
# LoanTerm                                 1
# PurposeoftheLoan                      auto
# Collateral                              No
# InterestRate                             5
# PreviousLoans                            0
# ExistingLiabilities                   4095
# ApplicationBehavior                 Normal
# LocationofApplication              Unusual
# ChangeinBehavior                        No
# TimeofTransaction                    02:00
# AccountActivity                     Normal
# PaymentBehavior                    On-time
# Blacklists                             Yes
# EmploymentVerification        Not Verified
# PastFinancialMalpractices               No
# DeviceInformation                   Mobile
# SocialMediaFootprint                    No
# ConsistencyinData             Inconsistent
# Referral                            Online
# Name: 26, dtype: object
# Row 26:**************************************Fraud Detected
# Age                                    22
# Occupation                     Technician
# MaritalStatus                      Single
# Dependents                              0
# ResidentialStatus                     Own
# AddressDuration                        88
# CreditScore                           627
# IncomeLevel                          6692
# LoanAmountRequested                 62698
# LoanTerm                                5
# PurposeoftheLoan                     auto
# Collateral                             No
# InterestRate                            6
# PreviousLoans                           0
# ExistingLiabilities                  4575
# ApplicationBehavior                Normal
# LocationofApplication             Unusual
# ChangeinBehavior                       No
# TimeofTransaction                   16:00
# AccountActivity                    Normal
# PaymentBehavior                      Late
# Blacklists                             No
# EmploymentVerification           Verified
# PastFinancialMalpractices              No
# DeviceInformation                  Mobile
# SocialMediaFootprint                   No
# ConsistencyinData            Inconsistent
# Referral                           Online
# Name: 27, dtype: object
# Row 27:**************************************Fraud Detected
# Age                                    22
# Occupation                       Musician
# MaritalStatus                      Single
# Dependents                              0
# ResidentialStatus                    Rent
# AddressDuration                        78
# CreditScore                           691
# IncomeLevel                         10646
# LoanAmountRequested                 55832
# LoanTerm                                4
# PurposeoftheLoan                 personal
# Collateral                             No
# InterestRate                          4.5
# PreviousLoans                           1
# ExistingLiabilities                  3389
# ApplicationBehavior                 Rapid
# LocationofApplication             Unusual
# ChangeinBehavior                       No
# TimeofTransaction                   09:40
# AccountActivity                   Unusual
# PaymentBehavior                 Defaulted
# Blacklists                            Yes
# EmploymentVerification       Not Verified
# PastFinancialMalpractices              No
# DeviceInformation                  Mobile
# SocialMediaFootprint                   No
# ConsistencyinData            Inconsistent
# Referral                           Online
# Name: 28, dtype: object
# Row 28:**************************************Fraud Detected
# Age                                    22
# Occupation                     Unemployed
# MaritalStatus                      Single
# Dependents                              1
# ResidentialStatus                    Rent
# AddressDuration                        85
# CreditScore                           818
# IncomeLevel                          7470
# LoanAmountRequested                  2000
# LoanTerm                                1
# PurposeoftheLoan                 personal
# Collateral                             No
# InterestRate                          4.5
# PreviousLoans                           1
# ExistingLiabilities                  5238
# ApplicationBehavior                Normal
# LocationofApplication             Unusual
# ChangeinBehavior                       No
# TimeofTransaction                   11:00
# AccountActivity                   Unusual
# PaymentBehavior                 Defaulted
# Blacklists                             No
# EmploymentVerification       Not Verified
# PastFinancialMalpractices              No
# DeviceInformation                  Mobile
# SocialMediaFootprint                   No
# ConsistencyinData            Inconsistent
# Referral                           Online
# Name: 29, dtype: object
# Row 29:**************************************Fraud Detected
